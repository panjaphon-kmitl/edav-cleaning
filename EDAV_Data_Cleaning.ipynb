# %% [markdown]
# ## อ่านข้อมูล Original

# %%
import pandas as pd
import numpy as np
import random

# %%
url = 'https://raw.githubusercontent.com/panjaphon-kmitl/edav-cleaning/main/data_Changed_Data_Types.xlsx'
path = 'data_Changed_Data_Types.xlsx'

# %%
try:
    original = pd.read_excel(url)
except:
    original = pd.read_excel(path)

# %%
original
# Out:
#            country     location_name  latitude  longitude         timezone  \
# 0      Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# 1          Albania            Tirana     41.33      19.82    Europe/Tirane
# 2          Algeria           Algiers     36.76       3.05   Africa/Algiers
# 3          Andorra  Andorra La Vella     42.50       1.52   Europe/Andorra
# 4           Angola            Luanda     -8.84      13.23    Africa/Luanda
# ...            ...               ...       ...        ...              ...
# 18588    Venezuela           Caracas     10.50     -66.92  America/Caracas
# 18589      Vietnam             Hanoi     21.03     105.85     Asia/Bangkok
# 18590        Yemen             Sanaa     15.35      44.21        Asia/Aden
# 18591       Zambia            Lusaka    -15.42      28.28    Africa/Lusaka
# 18592     Zimbabwe            Harare    -17.82      31.04    Africa/Harare
#
#        last_updated_epoch  last_updated  temperature_celsius  \
# 0              1715849100  45428.552083                 26.6
# 1              1715849100  45428.447917                 19.0
# 2              1715849100  45428.406250                 23.0
# 3              1715849100  45428.447917                  6.3
# 4              1715849100  45428.406250                 26.0
# ...                   ...           ...                  ...
# 18588          1724156100  45524.343750                 27.2
# 18589          1724156100  45524.802083                 32.1
# 18590          1724156100  45524.635417                 24.3
# 18591          1724156100  45524.593750                 26.2
# 18592          1724156100  45524.593750                 25.3
#
#        temperature_fahrenheit                       condition_text  ...  \
# 0                        79.8                        Partly Cloudy  ...
# 1                        66.2                        Partly cloudy  ...
# 2                        73.4                                Sunny  ...
# 3                        43.3                        Light drizzle  ...
# 4                        78.8                        Partly cloudy  ...
# ...                       ...                                  ...  ...
# 18588                    81.0                                Sunny  ...
# 18589                    89.8  Moderate or heavy rain with thunder  ...
# 18590                    75.8                   Patchy rain nearby  ...
# 18591                    79.1                                Sunny  ...
# 18592                    77.5                                Sunny  ...
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0                    8.4              26.6                         1
# 1                    1.1               2.0                         1
# 2                   10.4              18.4                         1
# 3                    0.7               0.9                         1
# 4                  183.4             262.3                         5
# ...                  ...               ...                       ...
# 18588                8.0               9.9                         1
# 18589              108.5             120.9                         4
# 18590               23.1              82.3                         2
# 18591               15.9              23.9                         2
# 18592               13.2              17.0                         1
#
#       air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 0                              1  0.201389  0.784722  0.508333  0.049306
# 1                              1  0.222917  0.829167  0.540278  0.093056
# 2                              1  0.236111  0.826389  0.552083  0.093056
# 3                              1  0.271528  0.882639  0.591667  0.146528
# 4                             10  0.258333  0.746528  0.553472  0.026389
# ...                          ...       ...       ...       ...       ...
# 18588                          1  0.262500  0.779861  0.822222  0.293056
# 18589                         10  0.234028  0.765278  0.791667  0.243750
# 18590                          2  0.242361  0.765972  0.797917  0.260417
# 18591                          2  0.263889  0.750000  0.786806  0.285417
# 18592                          2  0.257639  0.740972  0.777083  0.279167
#
#            moon_phase  moon_illumination
# 0      Waxing Gibbous                 55
# 1      Waxing Gibbous                 55
# 2      Waxing Gibbous                 55
# 3      Waxing Gibbous                 55
# 4      Waxing Gibbous                 55
# ...               ...                ...
# 18588  Waning Gibbous                100
# 18589  Waning Gibbous                100
# 18590  Waning Gibbous                100
# 18591  Waning Gibbous                100
# 18592  Waning Gibbous                100
#
# [18593 rows x 41 columns]

# %% [markdown]
# ## วางยา 1 : ทำให้ NULL

# %%
def create_nulls(df, column_name, p):
    num_records_to_nullify = int(len(df) * p)
    indices_to_nullify = np.random.choice(df.index, num_records_to_nullify, replace=False)
    df.loc[indices_to_nullify, column_name] = np.nan

    return df

# %%
poisoned = original.copy()
poisoned = create_nulls(poisoned, 'latitude', 0.12)
poisoned = create_nulls(poisoned, 'longitude', 0.05)
poisoned = create_nulls(poisoned, 'moon_illumination', 0.14)
poisoned = create_nulls(poisoned, 'country', 0.04)
poisoned = create_nulls(poisoned, 'temperature_celsius', 0.01)
poisoned = create_nulls(poisoned, 'temperature_fahrenheit', 0.02)

# %% [markdown]
# ## วางยา 2 : สะกดคำในคอลัมน์ condition_text ผิด

# %%
# Dictionary of correct words and their misspelled versions
misspelled_words = {
    "Partly Cloudy": ["Partly Cluody", "Pratly Cloudy"],
    "Partly cloudy": ["Partly clody", "Pratly cloudy"],
    "Sunny": ["Sunnny"],
    "Overcast": ["Overcastt", "Overcst"],
    "Patchy rain nearby": ["Patchy rain nerby", "Patchy rain"],
    "Light rain": ["Light Rain"],
    "Mist": ["Mistt"],
    "Cloudy": ["Cloudyy"],
    "Thundery outbreaks in nearby": ["Thundery outbraks in nearby", "Thundery outbreaks", "Thunder Outbreaks", "Thunder Outbreak"],
    "Light rain shower": ["Light ran shower", "Ligt rain shower"],
}

def random_misspell(word, p):
    if random.random() <= p:
        if word in misspelled_words:
            return random.choice(misspelled_words[word])
        else:
            return word
    else:
        return word

# %%
poisoned_2 = poisoned.copy()
poisoned_2['condition_text'] = [random_misspell(i, 0.1) for i in poisoned_2['condition_text']]

# %% [markdown]
# ## วางยา 3 : เปลี่ยนชื่อบางประเทศเป็นพิมพ์ผิดและตัวย่อ

# %%
wrong_country_names = {
    "United States of America" : ["USA"],
    "Untied Kingdom" : ["UK"],
    "Phillippines" : ["Philippines", "PH"],
    "Brazil" : ["Brasil"]
}

def misspell_country(country, p):
    if random.random() <= p:
        if country in wrong_country_names:
            return random.choice(wrong_country_names[country])
        else:
            return country
    else:
        return country

# %%
poisoned_3 = poisoned_2.copy()
poisoned_3['country'] = [misspell_country(i, 0.4) for i in poisoned_3['country']]

# %% [markdown]
# ## วางยา 4 : ทำให้ Row ซ้ำ

# %%
def duplicate_rows(df, num_duplicates=5):
    # Randomly select rows to duplicate
    rows_to_duplicate = df.sample(n=num_duplicates, replace=True)

    # Append the duplicated rows to the original DataFrame
    df_with_duplicates = pd.concat([df, rows_to_duplicate], ignore_index=True)

    return df_with_duplicates

# %%
poisoned_4 = poisoned_3.copy()
poisoned_4 = duplicate_rows(poisoned_4, 7)

# %% [markdown]
# ## ข้อมูลหลังวางยา

# %%
poisoned_4
# Out:
#            country     location_name  latitude  longitude           timezone  \
# 0      Afghanistan             Kabul     34.52      69.18         Asia/Kabul
# 1          Albania            Tirana       NaN      19.82      Europe/Tirane
# 2          Algeria           Algiers     36.76       3.05     Africa/Algiers
# 3          Andorra  Andorra La Vella     42.50       1.52     Europe/Andorra
# 4           Angola            Luanda     -8.84      13.23      Africa/Luanda
# ...            ...               ...       ...        ...                ...
# 18595    Australia          Canberra    -35.28     149.22   Australia/Sydney
# 18596    Guatemala    Guatemala City     14.62        NaN  America/Guatemala
# 18597      Liberia          Monrovia      6.31     -10.80    Africa/Monrovia
# 18598     Slovakia        Bratislava     48.15      17.12  Europe/Bratislava
# 18599     Malaysia      Kuala Lumpur      3.17     101.70  Asia/Kuala_Lumpur
#
#        last_updated_epoch  last_updated  temperature_celsius  \
# 0              1715849100  45428.552083                 26.6
# 1              1715849100  45428.447917                 19.0
# 2              1715849100  45428.406250                 23.0
# 3              1715849100  45428.447917                  6.3
# 4              1715849100  45428.406250                 26.0
# ...                   ...           ...                  ...
# 18595          1716387300  45435.010417                  1.0
# 18596          1717596900  45448.343750                 22.0
# 18597          1721392200  45492.520833                 25.5
# 18598          1719063900  45465.656250                 26.1
# 18599          1721737800  45496.854167                 27.8
#
#        temperature_fahrenheit     condition_text  ...  air_quality_PM2.5  \
# 0                        79.8      Partly Cloudy  ...                8.4
# 1                        66.2      Partly cloudy  ...                1.1
# 2                        73.4              Sunny  ...               10.4
# 3                        43.3      Light drizzle  ...                0.7
# 4                        78.8      Partly cloudy  ...              183.4
# ...                       ...                ...  ...                ...
# 18595                    33.8              Clear  ...                2.7
# 18596                    71.6              Mistt  ...              137.8
# 18597                    77.9  Light rain shower  ...                1.3
# 18598                    79.0      Partly cloudy  ...                2.8
# 18599                    82.0              Clear  ...               97.7
#
#        air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0                  26.6                         1                          1
# 1                   2.0                         1                          1
# 2                  18.4                         1                          1
# 3                   0.9                         1                          1
# 4                 262.3                         5                         10
# ...                 ...                       ...                        ...
# 18595               5.9                         1                          1
# 18596             179.7                         4                         10
# 18597               5.3                         1                          1
# 18598               3.0                         1                          1
# 18599             117.0                         4                         10
#
#         sunrise    sunset  moonrise   moonset       moon_phase  \
# 0      0.201389  0.784722  0.508333  0.049306   Waxing Gibbous
# 1      0.222917  0.829167  0.540278  0.093056   Waxing Gibbous
# 2      0.236111  0.826389  0.552083  0.093056   Waxing Gibbous
# 3      0.271528  0.882639  0.591667  0.146528   Waxing Gibbous
# 4      0.258333  0.746528  0.553472  0.026389   Waxing Gibbous
# ...         ...       ...       ...       ...              ...
# 18595  0.288889  0.710417  0.664583  0.224306   Waxing Gibbous
# 18596  0.230556  0.770139  0.188194  0.747917  Waning Crescent
# 18597  0.275000  0.793750  0.729167  0.186806   Waxing Gibbous
# 18598  0.202083  0.872222  0.920139  0.185417        Full Moon
# 18599  0.300000  0.811111  0.890972  0.365972   Waning Gibbous
#
#        moon_illumination
# 0                   55.0
# 1                    NaN
# 2                   55.0
# 3                   55.0
# 4                   55.0
# ...                  ...
# 18595               97.0
# 18596                NaN
# 18597               92.0
# 18598              100.0
# 18599                NaN
#
# [18600 rows x 41 columns]
